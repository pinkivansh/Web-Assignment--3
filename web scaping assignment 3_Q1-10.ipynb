# %% [markdown]
#                                       Web Scraping Assignment-3

# %% [markdown]
# 1. Write a python program which searches all the product under a particular product from www.amazon.in.
# The product to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search
# for guitars.

# %%
# Importing Libraries
import selenium
import pandas as pd
import time
#from bs4 import Beautifulsoup
from bs4 import BeautifulSoup 
# Importing selenium webdriver
from selenium import webdriver

# %%
# Importing required Exceptions which needs to handled
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
# Importing requests
import requests

# Importing regex
import re
import warnings
warnings.filterwarnings("ignore")

# %%
# Activating the chrome browser
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
url = "https://www.amazon.in/"
driver.get(url)

# %%
time.sleep(2)
# Asking the user to input the keywords he/she wants to search
user_inp = input('Enter the item name to be search : ')
# Out:
# Enter the product you want to search : guitar

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox")      
search_bar.clear()                                                 
search_bar.send_keys(user_inp)                                     
search_button = driver.find_element_by_xpath('//div[@class="nav-search-submit nav-sprite"]/span/input')

# %%
search_button.click()

# %% [markdown]
# _______________________________________________________________________________________________________________________________

# %% [markdown]
# 2. In the above question, now scrape the following details of each product listed in first 3 pages of your
# search results and save it in a data frame and csv. In case if any product has less than 3 pages in search
# results then scrape all the products available under that product name. Details to be scraped are: "Brand
# Name", "Name of the Product", "Price", "Return/Exchange", "Expected Delivery", "Availability" and
# “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
produrl = []

# %%
produrl_tag = driver.find_elements_by_xpath("//a[@class = 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")

# %%
for i in produrl_tag:
    try:
        produrl.append(i.get_attribute("href"))
    except:
        produrl.append('-')

# %%
n = 2

while (n>0):
    nextbtn = driver.find_element_by_xpath("//a[@class = 's-pagination-item s-pagination-next s-pagination-button s-pagination-separator']")
    nextbtn.click()
    time.sleep(3)
    produrl_tag = driver.find_elements_by_xpath("//a[@class = 'a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal']")
    for u in produrl_tag:
        produrl.append(u.get_attribute("href"))
    n=n-1

# %%
Brand = []
Product_Name = []
Price = []
Return_Exchange = []
Expected_Delivery = []
Availability = []
Product_Url = []

# %%
for n in produrl:
    driver.get(n)
    time.sleep(2)
    try:
        brandtag = driver.find_element_by_xpath("//td[@class = 'a-size-base prodDetAttrValue']")
        Brand.append(brandtag.text)
    except:
        Brand.append('-')
    try:
        prodtag = driver.find_element_by_xpath("//span[@id = 'productTitle']")
        Product_Name.append(prodtag.text)
    except:
        Product_Name.append('-')
    try:
        pricetag = driver.find_element_by_xpath("//span[@class = 'a-price a-text-price a-size-medium apexPriceToPay']")
        Price.append(pricetag.text)
    except:
        Price.append('-')
    try:
        retexctag = driver.find_element_by_xpath('//*[@id="icon-farm-container"]/div/div[1]/span/div[2]/a')
        Return_Exchange.append(retexctag.text)
    except:
        Return_Exchange.append('-')
    try:
        exptdeltag = driver.find_element_by_xpath("//div[@id = 'ddmDeliveryMessage']")
        Expected_Delivery.append(exptdeltag.text)
    except:
        Expected_Delivery.append('-')
    try:
        availabltag = driver.find_element_by_xpath("//div[@id = 'availability']/span")
        Availability.append(availabltag.text)
    except:
        Availability.append('-')

# %%
guitar = {'Brand Name':Brand,'Product Name':Product_Name,'Price':Price,'Return & Exchange':Return_Exchange,'Exp Deleviry':Expected_Delivery,'Availability':Availability,'Product Url':produrl}

guitar1 = pd.DataFrame(guitar)

# %%
guitar1
# Out:
#                            Brand Name  \
# 0                             Kadence
# 1                            Medellin
# 2                               VAULT
# 3                              Giuson
# 4     98 x 40 x 10 cm; 2.06 Kilograms
# ..                                ...
# 137  103 x 47 x 14 cm; 2.46 Kilograms
# 138                             Kordz
# 139                           Kadence
# 140                      HRB musicals
# 141                      HRB MUSICALS
#
#                                           Product Name      Price  \
# 0    Kadence Guitar Acoustica Series, Electric Acou...  ₹6,499.00
# 1    Medellin 38" Acoustic Guitar Blue Burst Carbon...  ₹2,299.00
# 2            Vault ST1 Premium Electric Guitar - White  ₹6,991.00
# 3    Giuson Venus Rosewood Acoustic Guitar With Bag...          -
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  ₹1,799.00
# ..                                                 ...        ...
# 137  JUAREZ Arpeggio 99.06 cm (39 Inch) Semi-Acoust...          -
# 138  Kordz Luana Red 41 Inch Rosewood Fretboard Aco...  ₹3,395.00
# 139  Kadence Frontier Series Acoustic Guitar With E...          -
# 140  HRB MUSICALS combo of guitar String Winder, gu...          -
# 141  HRB MUSICALS GUITAR FLOOR STAND +GUITAR CAPO +...          -
#
#       Return & Exchange                              Exp Deleviry  \
# 0                     -    FREE delivery: Tuesday, Jan 25 Details
# 1                     -    FREE delivery: Tuesday, Jan 25 Details
# 2                     -  FREE delivery: Wednesday, Jan 26 Details
# 3                     -     FREE delivery: Tuesday, Feb 1 Details
# 4                     -     FREE delivery: Friday, Jan 28 Details
# ..                  ...                                       ...
# 137                   -   FREE delivery: Thursday, Jan 27 Details
# 138                   -     FREE delivery: Tuesday, Feb 1 Details
# 139  7 Days Replacement          ₹499.00 delivery: Jan 31 - Feb 1
# 140  7 Days Replacement    FREE delivery: Tuesday, Jan 25 Details
# 141  7 Days Replacement    FREE delivery: Tuesday, Jan 25 Details
#
#               Availability                                        Product Url
# 0                In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 1                           https://www.amazon.in/gp/slredirect/picassoRed...
# 2    Only 1 left in stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 3    Only 1 left in stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 4                In stock.  https://www.amazon.in/Juarez-Acoustic-Cutaway-...
# ..                     ...                                                ...
# 137              In stock.  https://www.amazon.in/JUAREZ-Arpeggio-Semi-Aco...
# 138              In stock.  https://www.amazon.in/Kordz-Luana-Red-Rosewood...
# 139              In stock.  https://www.amazon.in/Kadence-Frontier-Acousti...
# 140              In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
# 141              In stock.  https://www.amazon.in/gp/slredirect/picassoRed...
#
# [142 rows x 7 columns]

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10
# images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
# Opening the google images

url = "https://images.google.com/"
driver.get(url)

# %%
urls = []
data = []
search_item = ["Fruits","Cars","Machine Learning","Guitar","Cakes"]

# %%
for item in search_item:
    driver.get(url)
    time.sleep(4)
    search_bar = driver.find_element_by_tag_name("input")
    search_bar.send_keys(str(item))
    search_bttn = driver.find_element_by_xpath("//button[@class = 'Tg7LZd']").click()

# %%
# Scrolling the web page to get more images
    
for _ in range(500):
    driver.execute_script("window.scrollBy(0,20)")
    
    imges = driver.find_elements_by_xpath("//img[@class = 'rg_i Q4LuWd']")
img_url = []
    
for image in imges:
    source = image.get_attribute('src')
    if source is not None:
        if (source[0:4] =='http'):
            img_url.append(source)

for i in img_url[:10]:
    urls.append(i)
    
for i in range(len(urls)):
    if i >= 10:
        break
        
    print("Downloading {0} of {1} images".format(i,10))
    response = requests.get(urls[i])
    file1 = open(r"D:\D:\Images"+str(i)+".jpg","wb")
        
    file1.write(response.content)

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”, “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the details is missing then replace it by “- “. Save your results in a dataframe and CSV

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.flipkart.com/')
#closing the login box

close_button = driver.find_element_by_xpath("//button[@class = '_2KpZ6l _2doB4z']")
close_button.click()

# %%
prod_name = input("Enter the Product Name : ")
# Out:
# Enter the Product Name : samsung

# %%
search_bar = driver.find_element_by_xpath("//div[@class = '_3OO5Xc']//input")
search_bar.send_keys(prod_name)

search_bttn = driver.find_element_by_xpath("//button[@class = 'L0Z3Pu']").click()

# %%
page1 = []

page1_url = driver.find_elements_by_xpath("//a[@class = '_1fQZEK']")

for url in page1_url:
    page1.append(url.get_attribute("href"))

# %%
len(page1)
# Out:
# 24

# %%
Brand_Name = []
Smartphone_Name = []
Color = []
RAM = []
ROM = []
Primary_Camera = []
Secondary_Camera = []
Display_Size = []
Battery_Capacity = []
Price = []

# %%
for i in page1:
    driver.get(i)
    time.sleep(3)
    morebttn = driver.find_element_by_xpath("//button[@class = '_2KpZ6l _1FH0tX']")
    morebttn.click()
    time.sleep(5)
    try: 
        brandtag = driver.find_element_by_xpath("//span[@class = 'B_NuCI']")
        Brand_Name.append(brandtag.text.split()[0])
    except:
        Brand_Name.append('-')
    try:
        smartphtag = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][1]/table[1]/tbody/tr[3]/td[2]/ul/li")
        Smartphone_Name.append(smartphtag.text)
    except:
        Smartphone_Name.append('-')
    try:
        colortag = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][1]/table[1]/tbody/tr[4]/td[2]/ul/li")
        Color.append(colortag.text)
    except:
        Color.append('-')
    try:
        ram_tag = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][4]/table[1]/tbody/tr[2]/td[2]/ul/li")
        RAM.append(ram_tag.text)
    except:
        RAM.append('-')
    try:
        rom_tag = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][4]/table[1]/tbody/tr[1]/td[2]/ul/li")
        ROM.append(rom_tag.text)
    except:
        ROM.append('-')
    try:
        p_camera = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][5]/table[1]/tbody/tr[2]/td[2]/ul/li")
        Primary_Camera.append(p_camera.text)
    except:
        Primary_Camera.append('-')
    try:
        s_camera = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][5]/table[1]/tbody/tr[5]/td[2]/ul/li")
        Secondary_Camera.append(s_camera.text)
    except:
        Secondary_Camera.append('-')
    try:
        dtag = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][2]/table[1]/tbody/tr[1]/td[2]/ul/li")
        Display_Size.append(dtag.text)
    except:
        Display_Size.append('-')
    try:
        btag = driver.find_element_by_xpath("//div[@class = '_3k-BhJ'][10]/table[1]/tbody/tr[1]/td[2]/ul/li")
        Battery_Capacity.append(btag.text)
    except:
        Battery_Capacity.append('-')
    try:
        pricetag = driver.find_element_by_xpath("//div[@class = '_30jeq3 _16Jk6d']")
        Price.append(pricetag.text)
    except:
        Price.append('-')

# %%
print(len(Brand_Name),len(Smartphone_Name),len(Color),len(RAM),len(ROM),len(Primary_Camera),len(Secondary_Camera),len(Display_Size),len(Battery_Capacity),len(Price))
# Out:
# 24 24 24 24 24 24 24 24 24 24

# %%
Smart_phone = {"Brand Name": Brand_Name,"Smartphone Name":Smartphone_Name,"Color":Color,"RAM":RAM,"Internal Storage(ROM)":ROM,"Primary Camera":Primary_Camera,"Secondary Camera":Secondary_Camera,"Display Size":Display_Size,"Battery Capacity":Battery_Capacity,"Product Price":Price}

# %%
phone = pd.DataFrame(Smart_phone)
phone.reset_index(drop = True, inplace = True)
phone.index+=1

# %%
phone
# Out:
#    Brand Name   Smartphone Name            Color   RAM Internal Storage(ROM)  \
# 1     SAMSUNG        Galaxy F12        Sea Green  4 GB                 64 GB
# 2     SAMSUNG        Galaxy F12         Sky Blue  4 GB                 64 GB
# 3     SAMSUNG        Galaxy F12  Celestial Black  4 GB                 64 GB
# 4     SAMSUNG        Galaxy F12        Sea Green  4 GB                128 GB
# 5     SAMSUNG        Galaxy F22      Denim Black  4 GB                 64 GB
# 6     SAMSUNG        Galaxy F22       Denim Blue  4 GB                 64 GB
# 7     SAMSUNG        Galaxy F12         Sky Blue  4 GB                128 GB
# 8     SAMSUNG        Galaxy F12  Celestial Black  4 GB                128 GB
# 9     SAMSUNG        Galaxy M12            Black  4 GB                 64 GB
# 10    SAMSUNG     Galaxy F42 5G      Matte Black  6 GB                128 GB
# 11    SAMSUNG     Galaxy F42 5G       Matte Aqua  6 GB                128 GB
# 12    SAMSUNG        Galaxy M32            Black  4 GB                 64 GB
# 13    SAMSUNG        Galaxy M12            White  4 GB                 64 GB
# 14    SAMSUNG        Galaxy A52    Awesome Black  6 GB                128 GB
# 15    SAMSUNG        Galaxy M12            Black  6 GB                128 GB
# 16    SAMSUNG     Galaxy F42 5G      Matte Black  8 GB                128 GB
# 17    SAMSUNG        Galaxy M12            White  6 GB                128 GB
# 18    SAMSUNG     Galaxy F42 5G       Matte Aqua  8 GB                128 GB
# 19    SAMSUNG     Galaxy A22 5G           Violet  6 GB                128 GB
# 20    SAMSUNG         GURU 1200            Black   GSM                    2G
# 21    SAMSUNG        Galaxy M12             Blue  6 GB                128 GB
# 22    SAMSUNG     Galaxy M32 5G         Sky Blue  8 GB                128 GB
# 23    SAMSUNG        Galaxy A32     Awesome Blue  8 GB                128 GB
# 24    SAMSUNG  M21 2021 Edition   Charcoal Black  4 GB                 64 GB
#
#              Primary Camera   Secondary Camera           Display Size  \
# 1    48MP + 5MP + 2MP + 2MP   8MP Front Camera  16.55 cm (6.515 inch)
# 2    48MP + 5MP + 2MP + 2MP   8MP Front Camera  16.55 cm (6.515 inch)
# 3    48MP + 5MP + 2MP + 2MP   8MP Front Camera  16.55 cm (6.515 inch)
# 4    48MP + 5MP + 2MP + 2MP   8MP Front Camera  16.55 cm (6.515 inch)
# 5    48MP + 8MP + 2MP + 2MP  13MP Front Camera    16.26 cm (6.4 inch)
# 6    48MP + 8MP + 2MP + 2MP  13MP Front Camera    16.26 cm (6.4 inch)
# 7    48MP + 5MP + 2MP + 2MP   8MP Front Camera  16.55 cm (6.515 inch)
# 8    48MP + 5MP + 2MP + 2MP   8MP Front Camera  16.55 cm (6.515 inch)
# 9            Primary Camera                  -    16.51 cm (6.5 inch)
# 10         64MP + 5MP + 2MP   8MP Front Camera    16.76 cm (6.6 inch)
# 11         64MP + 5MP + 2MP   8MP Front Camera    16.76 cm (6.6 inch)
# 12   64MP + 8MP + 2MP + 2MP  20MP Front Camera    16.26 cm (6.4 inch)
# 13           Primary Camera                  -    16.51 cm (6.5 inch)
# 14  64MP + 12MP + 5MP + 5MP  32MP Front Camera    16.51 cm (6.5 inch)
# 15           Primary Camera                  -    16.51 cm (6.5 inch)
# 16         64MP + 5MP + 2MP   8MP Front Camera    16.76 cm (6.6 inch)
# 17           Primary Camera                  -    16.51 cm (6.5 inch)
# 18         64MP + 5MP + 2MP   8MP Front Camera    16.76 cm (6.6 inch)
# 19         48MP + 5MP + 2MP   8MP Front Camera    16.76 cm (6.6 inch)
# 20                        -                  -    3.86 cm (1.52 inch)
# 21           Primary Camera                  -    16.51 cm (6.5 inch)
# 22   48MP + 8MP + 5MP + 2MP  13MP Front Camera    16.51 cm (6.5 inch)
# 23   64MP + 8MP + 5MP + 5MP  20MP Front Camera    16.26 cm (6.4 inch)
# 24           Primary Camera                  -    16.26 cm (6.4 inch)
#
#                                      Battery Capacity Product Price
# 1                                            6000 mAh       ₹11,499
# 2                                            6000 mAh       ₹11,499
# 3                                            6000 mAh       ₹11,499
# 4                                            6000 mAh       ₹12,499
# 5                                            6000 mAh       ₹12,999
# 6                                            6000 mAh       ₹12,999
# 7                                            6000 mAh       ₹12,499
# 8                                            6000 mAh       ₹12,499
# 9                                                   -       ₹11,374
# 10                                           5000 mAh       ₹20,999
# 11                                           5000 mAh       ₹20,999
# 12                                              74 mm       ₹14,990
# 13                                                  -       ₹11,363
# 14                                            75.1 mm       ₹24,568
# 15                                                  -       ₹13,825
# 16                                           5000 mAh       ₹22,999
# 17                                                  -       ₹13,864
# 18                                           5000 mAh       ₹22,999
# 19                                           5000 mAh       ₹19,990
# 20                                                  -        ₹1,639
# 21                                                  -       ₹14,177
# 22  1 Year Warranty Provided by the Manufacturer f...       ₹20,120
# 23                                           5000 mAh       ₹23,499
# 24                                                  -       ₹13,398

# %%
# saving file as csv

phone.to_csv('FlipkartSmartphone.csv')

# %% [markdown]
# 5.Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://maps.google.com/')

# %%
city = input("Enter the city name : ")
# Out:
# Enter the city name : Durgapur

# %%
search_city = driver.find_element_by_xpath("//input[@class = 'tactile-searchbox-input']")
search_city.send_keys(city)
search_bttn = driver.find_element_by_xpath("//button[@class = 'nhb85d-BIqFsb']").click()

# %%
current_url = driver.current_url

value = current_url.split("@")[1]

v1 = value.split(",",2)

print("Latitude ::",v1[0])
print("Longitude ::",v1[1])
# Out:
# Latitude :: 23.531088
# Longitude :: 87.2301333

# %% [markdown]
# 6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://trak.in')

# %%
button = driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href')
driver.get(button)

# %%
Date = []
Name = []
Vertical = []
Sub_Vertical = []
Location = []
Investor_Name = []
Type = []
Money = []

# %%
for i in range(54,57):
    
    try:
        date_tag = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[2]")
        for i in date_tag:
            Date.append(i.text)
    except:
        Date.append('-')
        
for i in range(54,57):
    try:
        name_tag = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[3]/a")
        for i in name_tag:
            Name.append(i.text)
    except:
        Name.append('-')
        
for i in range(54,57):
    try:
        vert_tag = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[4]")
        for i in vert_tag:
            Vertical.append(i.text)
    except:
        Vertical.append('-')
        
for i in range(54,57):
    try:
        subvert_tag = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[5]")
        for i in subvert_tag:
            Sub_Vertical.append(i.text)
    except:
        Sub_Vertical.append('-')
        
for i in range(54,57):
    try:
        location_tag = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[6]")
        for i in location_tag:
            Location.append(i.text)
    except:
        Location.append('-')
        
for i in range(54,57):
    try:
        instname = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[7]")
        for i in instname:
            Investor_Name.append(i.text)
    except:
        Investor_Name.append('-')
        
for i in range(54,57):
    try:
        inst_type = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[8]")
        for i in inst_type:
            Type.append(i.text)
    except:
        Type.append('-')
        
for i in range(54,57):
    try:
        amt_tag = driver.find_elements_by_xpath(f"//*[@id = 'tablepress-{i}']/tbody/tr/td[9]")
        for i in amt_tag:
            Money.append(i.text)
    except:
        Money.append('-')

# %%
StartUp = {'Date':Date,'Startup Name':Name,'Industry/Vertical':Vertical,'Sub-Vertical':Sub_Vertical,'City/Location':Location,'Investor Name':Investor_Name,"Investment Type":Type,"Amount":Money}
startup = pd.DataFrame(StartUp)

# %%
startup
# Out:
#           Date            Startup Name       Industry/Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  04/03/2021               DealShare              E-commerce
# 18  31/03/2021                Uniphore              Technology
# 19  30/03/2021                   Dunzo              E-commerce
# 20  30/03/2021                  BYJU’S                Edu-tech
# 21  23/03/2021             SkilloVilla                Edu-tech
# 22  25/03/2021                CityMall              E-commerce
# 23  26/03/2021                   DotPe                 FinTech
#
#                                          Sub-Vertical      City/Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                           Online shopping platform  Jaipur, Rajasthan
# 18            Conversational Service Automation (CSA)          Palo Alto
# 19                           Hyper-local delivery app          Bengaluru
# 20                                    Online tutoring          Bengaluru
# 21                Career and job-oriented upskilling.          Bengaluru
# 22       Social ecommerce and online grocery platform            Gurgaon
# 23  Commerce and payments platform to offline ente...            Gurgaon
#
#                                         Investor Name Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17                                    Innoven Capital  Debt Financing
# 18                          Sorenson Capital Partners        Series D
# 19                          Krishtal Advisors Pte Ltd        Series E
# 20         MC Global Edtech, B Capital, Baron, others        Series F
# 21                              Titan Capital, others            Seed
# 22                                     Accel Partners        Series A
# 23                                               PayU        Series A
#
#           Amount
# 0    1,80,00,000
# 1   6,172,258.50
# 2     30,000,000
# 3     15,000,000
# 4     16,000,000
# 5     15,000,000
# 6    100,000,000
# 7      4,000,000
# 8      2,500,000
# 9    250,000,000
# 10  2,747,045.20
# 11   1,50,00,000
# 12    75,000,000
# 13     4,773,958
# 14    55,000,000
# 15    15,000,000
# 16    18,000,000
# 17   250,000,000
# 18   140,000,000
# 19     8,000,000
# 20   460,000,000
# 21   300,000,000
# 22    11,000,000
# 23    27,500,000

# %% [markdown]
# 7. Write a program to scrap all the available details of best gaming laptops from digit.in

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.digit.in/')

# %%
laptop = driver.find_element_by_xpath('/html/body/div[2]/div/div[4]/ul/li[3]/a')
laptop.click()

# %%
bestgaminglaptop = driver.find_element_by_xpath('/html/body/div[7]/div/div[2]/div[2]/ul/li[10]/a')
bestgaminglaptop.click()

# %%
name = []
OS = []
Display = []
Processor = []
Memory = []
Weight = []
Dimension = []
Graphics_Processor = []
Price = []

# %%
name_tag = driver.find_elements_by_xpath("//*[@id = 'summtable']/tbody/tr/td[1]")
for n in name_tag:
    name.append(n.text)
    
price_tag = driver.find_elements_by_xpath("//*[@id = 'summtable']/tbody/tr/td[3]")
for i in price_tag:
    Price.append(i.text)
    
disp_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[4]/td[3]")
for j in disp_tag:
    Display.append(j.text)
    
proc_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[5]/td[3]")
for k in proc_tag:
    Processor.append(k.text)
    
mem_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[6]/td[3]")
for l in mem_tag:
    Memory.append(l.text)
    
weight_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[7]/td[3]")
for m in weight_tag:
    Weight.append(m.text)
    
dimen_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[8]/td[3]")
for b in dimen_tag:
    Dimension.append(b.text)
    
grap_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[9]/td[3]")
for d in grap_tag:
    Graphics_Processor.append(d.text)
    
os_tag = driver.find_elements_by_xpath("//div[@class = 'Spcs-details']/table/tbody/tr[3]/td[3]")
for h in os_tag:
    OS.append(h.text)

# %%
Gaming_Laptop = {"Brand Name":name,"Operating System":OS,"Display":Display,"Processor":Processor,"Memory":Memory,"Weight in KG":Weight,"Dimension":Dimension,"Graphics Processor":Graphics_Processor,"Price in INR":Price}
Gaming_Laptop = pd.DataFrame(Gaming_Laptop)
Gaming_Laptop.reset_index(drop = True, inplace = True)
Gaming_Laptop.index+=1

# %%
Gaming_Laptop
# Out:
#                      Brand Name Operating System              Display  \
# 1                  Acer Nitro 5       Windows 10  15.6" (1920 x 1080)
# 2               MSI Stealth 15M       Windows 10  15.6" (1920 x 1080)
# 3        ASUS ROG Strix Scar 15       Windows 10  15.6" (2560 x 1440)
# 4         Alienware Area 51M R2  Windows 10 Home  17.3" (1920 x 1080)
# 5              Alienware m15 R3  Windows 10 Home  15.6" (3840 x 2160)
# 6        ASUS ROG Strix Scar 15  Windows 10 Home  15.6" (1920 x 1080)
# 7             ASUS ZEPHYRUS G14  Windows 10 Home    14" (1920 x 1080)
# 8              Lenovo Legion 5i   Windows 10 Pro  15.6" (1920 x 1080)
# 9      ASUS ROG ZEPHYRUS DUO 15       Windows 10  15.6" (3840 x 1100)
# 10  Acer Aspire 7 gaming laptop  Windows 10 Home  15.6" (1920 x 1080)
#
#                                      Processor                  Memory  \
# 1              AMD Ryzen 9 Octa Core | 2.4 GHz   1 TB HDD/16 GBGB DDR4
# 2         Intel Core i7 11th Gen - 11375H | NA   1 TB SSD/16 GBGB DDR4
# 3     AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz   2 TB SSD/32 GBGB DDR4
# 4    10th Gen Intel® Core™ i7-10700 | 2.90 GHz   1 TB SSD/16 GBGB DDR4
# 5        10th Gen Intel® Core™ i9-10980HK | NA   1 TB SSD/16 GBGB DDR4
# 6                AMD Ryzen™ 9 5900HX | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 7                AMD 3rd Gen Ryzen 9 | 3.3 GHz   1 TB SSD/16 GBGB DDR4
# 8   10th Gen Intel® Core™ i5-10300H | 2.50 GHz   1 TB SSD/16 GBGB DDR4
# 9           Intel Core i7 10th Gen 10875H | NA  512 GB SSD/4 GBGB DDR4
# 10           AMD Ryzen™ 5-5500U hexa-core | NA  512 GB SSD/8 GBGB DDR4
#
#    Weight in KG                Dimension             Graphics Processor  \
# 1           2.4       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070
# 2           1.7      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060
# 3          2.30         354 x 259 x 22.6        NVIDIA GeForce RTX 3080
# 4           4.1   27.65 x 402.6 x 319.14        Intel® UHD Graphics 630
# 5            NA                       NA                             NA
# 6          2.30       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070
# 7          1.65        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060
# 8           2.3  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB
# 9           2.4  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q
# 10         2.15       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650
#
#    Price in INR
# 1     ₹ 129,990
# 2     ₹ 134,990
# 3     ₹ 268,990
# 4     ₹ 342,989
# 5     ₹ 319,990
# 6     ₹ 215,990
# 7     ₹ 164,990
# 8      ₹ 76,988
# 9     ₹ 185,000
# 10     ₹ 57,900

# %% [markdown]
# 8. Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.forbes.com/')

# %%
explore_button = driver.find_element_by_xpath("//button[@class = 'icon--hamburger']")
explore_button.click()

# %%
#Clicking on Billionaires option
bill_button = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]')
bill_button.click()

#Clicking on World's Billionaries option
allbill = driver.find_element_by_xpath('/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a')
allbill.click()

# %%
Rank = []
Name = []
Net_Worth = []
Age = []
Citizenship = []
Source = []
Industry = []

# %%
rank_tag = driver.find_elements_by_xpath("//div[@class = 'rank']")
for i in rank_tag:
    Rank.append(i.text)
    
name_tag = driver.find_elements_by_xpath("//div[@class = 'personName']//div")
for j in name_tag:
    Name.append(j.text)

nworth_tag = driver.find_elements_by_xpath("//div[@class = 'netWorth']//div")
for k in nworth_tag:
    Net_Worth.append(k.text)
    
age_tag = driver.find_elements_by_xpath("//div[@class = 'age']//div")
for l in age_tag:
    Age.append(l.text)
    
citi_tag = driver.find_elements_by_xpath("//div[@class = 'countryOfCitizenship']")
for m in citi_tag:
    Citizenship.append(m.text)
    
source_tag = driver.find_elements_by_xpath("//div[@class = 'source-column']//div")
for n in source_tag:
    Source.append(n.text)
    
ind_tag = driver.find_elements_by_xpath("//div[@class = 'category']//div")
for o in ind_tag:
    Industry.append(o.text)

# %%
import time

e=0

while(e<=12):
    
    nextbtn = driver.find_element_by_xpath("//div[@class = 'next-page']")
    nextbtn.click()
    time.sleep(3)
    
    rank_tag = driver.find_elements_by_xpath("//div[@class = 'rank']")
    for i in rank_tag:
        Rank.append(i.text)
    
    name_tag = driver.find_elements_by_xpath("//div[@class = 'personName']//div")
    for j in name_tag:
        Name.append(j.text)

    nworth_tag = driver.find_elements_by_xpath("//div[@class = 'netWorth']//div")
    for k in nworth_tag:
        Net_Worth.append(k.text)
    
    age_tag = driver.find_elements_by_xpath("//div[@class = 'age']//div")
    for l in age_tag:
        Age.append(l.text)
    
    citi_tag = driver.find_elements_by_xpath("//div[@class = 'countryOfCitizenship']")
    for m in citi_tag:
        Citizenship.append(m.text)
    
    source_tag = driver.find_elements_by_xpath("//div[@class = 'source-column']//div")
    for n in source_tag:
        Source.append(n.text)
    
    ind_tag = driver.find_elements_by_xpath("//div[@class = 'category']//div")
    for o in ind_tag:
        Industry.append(o.text)
        
    e=e+1

# %%
#removing empty string value from Net_Worth
while('' in Net_Worth):
    Net_Worth.remove("")

# %%
#replacing unwanted symble with empty string

for i in range(0,len(Source)):
    if Source[i]=='★':
        Source[i]= ''

#removing empty string value from Source
while ('' in Source):
    Source.remove("")

# %%
Billonaires = {'Rank':Rank,'Name':Name,'Net Worth':Net_Worth,'Age':Age,'Citizenship':Citizenship,'Source':Source,'Industry':Industry}

Billonairesdf = pd.DataFrame(Billonaires)
Billonairesdf.reset_index(drop = True, inplace = True)
Billonairesdf.index+=1

# %%
Billonairesdf

# %% [markdown]
# 9.Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.youtube.com/')

# %%
search_bar = driver.find_element_by_xpath('/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search_bar.send_keys("Data Science")

search_bttn = driver.find_element_by_xpath('/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/button')
search_bttn.click()

time.sleep(2)

# %%
comments = []
comment_time = []
Likes = []
Time =[]
No_of_likes = []

# %%
link_click = driver.find_element_by_xpath("//yt-formatted-string[@class = 'style-scope ytd-video-renderer']")
link_click.click()

# %%
for i in range (1000):
    driver.execute_script("window.scrollBy(0,10000)")

# %%
cm_tags = driver.find_elements_by_id('content-text')
for cm in cm_tags:
    if cm.text is None:
        comments.append('--')
    else:
        comments.append(cm.text)

# %%
tm_tags = driver.find_elements_by_xpath("//a[contains(text(),'ago')]")
for tm in tm_tags:
    Time.append(tm.text)
    
for i in range(0,len(Time),2):
    comment_time.append(Time[i])
    
    
time.sleep(5)

# %%
# Scrapping the data of comment_likes

like_tags = driver.find_elements_by_xpath("//span[@class = 'style-scope ytd-comment-action-buttons-renderer']")
for like in like_tags:
    Likes.append(like.text)
    
for i in range(1,len(Likes),2):
    No_of_likes.append(Likes[i])
    

time.sleep(5)

# %%
print(len(comments)),print(len(comment_time)),print(len(No_of_likes))
# Out:
# 440
# 460
# 460
# (None, None, None)

# %%
df = {"Comments":comments[0:440],"Comments Time":comment_time[0:440],"Comment upvotes":No_of_likes[0:440]}

# %%
 pd.DataFrame(df)
# Out:
#                                               Comments          Comments Time  \
# 0                This guy deserves a Nobel prize!.....           7 months ago
# 1    I love the videos, Harry. Just a small correct...           7 months ago
# 2    You are idol for non tech background people wh...           7 months ago
# 3    I m surprise how fast ur ....learning technolo...           7 months ago
# 4    This is my favorite channel. I especially like...           7 months ago
# ..                                                 ...                    ...
# 435                               Angular playlist plz           7 months ago
# 436  I have a suggestion for freshers.DON'T  learn ...           7 months ago
# 437  sir your are op and vedio toooooooo \npls tell...  7 months ago (edited)
# 438             Sir Django me ERP system banaye plzzzz           7 months ago
# 439  Very helpful video bhaiya next video on AI dev...           7 months ago
#
#     Comment upvotes
# 0               426
# 1                53
# 2                 3
# 3               588
# 4                15
# ..              ...
# 435               1
# 436
# 437
# 438
# 439
#
# [440 rows x 3 columns]

# %% [markdown]
# 10. Write a python program to scrape a data for all available Hostels from https://www.hostelworld.com/ in “London” location. You have to scrape hostel name, distance from city centre, ratings, total reviews, overall reviews, privates from price, dorms from price, facilities and property description

# %%
driver = webdriver.Chrome(r'C:\Users\User\Downloads\chromedriver_win32\chromedriver.exe')

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get(' https://www.hostelworld.com/')

# %%
search_loc =driver.find_element_by_xpath("//input[@class = 'native-input body-1-reg sc-wds-search-input']")

# %%
search_loc.send_keys("London")
time.sleep(2)

# %%
london = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[1]/div/div[1]/div/div/div[1]/div/wds-search-dropdown/wds-search-list/wds-search-item[1]/div[2]/div[1]')
london.click()
time.sleep(2)

# %%
search_btn = driver.find_element_by_xpath('/html/body/div[3]/div/div/div[1]/div/div[1]/div/div/div[1]/wds-search-form-double-l/div[2]/div[2]/wds-button/button/span')
search_btn.click()

# %%
Hostel_Name = []
Distance_from_city = []
overall_review = []
total_reviews = []
facilities = []
price = []
Rating = []
property_description = []

# %%
while(True):
    
    # Hostel name
    names = driver.find_elements_by_xpath('//h2[@class="title title-6"]')
    for name in names:
        Hostel_Name.append(name.text)
    time.sleep(2)
        
    # Distance from city centre
    dis = driver.find_elements_by_xpath('//span[@class="description"]')
    for d in dis:
        Distance_from_city.append(d.text)
    time.sleep(2)
        
    # Overall Review    
    review = driver.find_elements_by_xpath('//div[@class="keyword"]//span')
    for r in review:
        overall_review.append(r.text)
    time.sleep(2)
    
    # Total No of reviews     
    t_review = driver.find_elements_by_xpath('//div[@class="reviews"]')
    for tr in t_review:
        total_reviews.append(tr.text)
    time.sleep(2)
    
    # facilities
    service = driver.find_elements_by_xpath('//div[@class="facilities-label facilities"]')
    for s in service:
        facilities.append(s.text)
    time.sleep(2)
    
    # Prices    
    prices = driver.find_elements_by_xpath('//div[@class="price-col"]')
    for p in prices:
        price.append(p.text)
    time.sleep(2)    
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break
        
time.sleep(4)        
        
# Separate  Privates_From price  and  Dorms_From price
Privates_From = []
for i in range(0,len(price),2):
    Privates_From.append(price[i])
time.sleep(2)

Dorms_From = []
for i in range(1,len(price),2):
    Dorms_From.append(price[i])

# %%
hostel_url = []

while(True):
    urls = driver.find_elements_by_xpath('//h2[@class="title title-6"]//a')
    for url in urls:
        hostel_url.append(url.get_attribute("href"))
    time.sleep(2)    
        
    try:
        next_button = driver.find_element_by_xpath('//div[@class="pagination-item pagination-next"]')
        next_button.click()
    except:
        break


        
Rate = []
for page in hostel_url:
    driver.get(page)
    
    # Rating
    try:
        ratings = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[1]/div[1]/div[1]')
        Rate.append(ratings.text)
    except NoSuchElementException:
        Rate.append("No Rating")  
    time.sleep(2)
    
    
    # Property Description
    try:
        pd = driver.find_element_by_xpath('/html/body/div[1]/div/div/div[1]/section/div[6]/div/div[2]/div[2]/div/div[2]')
        property_description.append(pd.text)
    except NoSuchElementException:
        property_description.append("No Description")  

    
time.sleep(2)        
# remove extra data from Rating     
all_text = []
for i in Rate:
    all_text.append(i.split())
time.sleep(2)

for i in all_text:
    Rating.append(i[0])

# %%
len(Rating)
# Out:
# 17

# %%
#creating dataframe
df = pd.DataFrame({'Hostel Name':Hostel_Name[0:50],
                'Distance from city centre':Distance_from_city[0:50],
                'Overall Review':overall_review[0:50],
                'Total Reviews':total_reviews[0:50],
                'Facilities':facilities[0:50],
                'Privates From Price':Privates_From[0:50],
                'Dorms From Price':Dorms_From[0:50]                })
df
# Out:
#                                 Hostel Name         Distance from city centre  \
# 0                         Mornington Camden   Hostel - 4.1km from city centre
# 1               Smart Russell Square Hostel   Hostel - 2.6km from city centre
# 2                   Smart Camden Inn Hostel   Hostel - 4.4km from city centre
# 3                             Selina Camden   Hostel - 5.5km from city centre
# 4                   Queen Elizabeth Chelsea   Hostel - 5.7km from city centre
# 5                             Pickwick Hall   Hostel - 2.3km from city centre
# 6                      New Cross Inn Hostel   Hostel - 6.1km from city centre
# 7              No.8 Willesden Hostel London    Hostel - 10km from city centre
# 8         Safestay London Elephant & Castle   Hostel - 1.7km from city centre
# 9                  Barmy Badger Backpackers   Hostel - 5.5km from city centre
# 10                   The London Home Hostel   Hostel - 8.2km from city centre
# 11                       No.8 Seven Sisters     Hostel - 9km from city centre
# 12                               Park Villa   Hostel - 6.3km from city centre
# 13                          Astor Hyde Park   Hostel - 4.3km from city centre
# 14          Wombat's The City Hostel London   Hostel - 3.6km from city centre
# 15               St Christopher's Greenwich   Hostel - 7.6km from city centre
# 16       St Christopher's Oasis-Female Only   Hostel - 1.8km from city centre
# 17                  St Christopher's Camden   Hostel - 4.3km from city centre
# 18          St Christopher's Shepherds Bush     Hostel - 7km from city centre
# 19             St Christopher's Hammersmith   Hostel - 7.5km from city centre
# 20  St Christopher's Inn - Liverpool Street   Hostel - 3.2km from city centre
# 21      PubLove @ The White Ferry, Victoria   Hostel - 2.4km from city centre
# 22               Smart Hyde Park Inn Hostel     Hostel - 5km from city centre
# 23              Smart Hyde Park View Hostel     Hostel - 5km from city centre
# 24  Safestay London Kensington Holland Park   Hostel - 5.9km from city centre
# 25                     Urbany Hostel London   Hostel - 5.4km from city centre
# 26                         Astor Kensington   Hostel - 4.9km from city centre
# 27                           Phoenix Hostel   Hostel - 4.2km from city centre
# 28                  Prime Backpackers Angel   Hostel - 3.6km from city centre
# 29                   YHA London Earls Court   Hostel - 5.1km from city centre
# 30                        Mornington Camden     Hostel - 3km from city centre
# 31              Smart Russell Square Hostel   Hostel - 2.2km from city centre
# 32                  Smart Camden Inn Hostel   Hostel - 1.8km from city centre
# 33                            Selina Camden   Hostel - 3.4km from city centre
# 34                  Queen Elizabeth Chelsea   Hostel - 3.3km from city centre
# 35                            Pickwick Hall   Hostel - 5.5km from city centre
# 36                     New Cross Inn Hostel   Hostel - 1.3km from city centre
# 37             No.8 Willesden Hostel London   Hostel - 3.2km from city centre
# 38        Safestay London Elephant & Castle   Hostel - 8.2km from city centre
# 39                 Barmy Badger Backpackers   Hostel - 4.1km from city centre
# 40                   The London Home Hostel   Hostel - 5.5km from city centre
# 41                       No.8 Seven Sisters   Hostel - 0.5km from city centre
# 42                               Park Villa  Hostel - 10.9km from city centre
# 43                          Astor Hyde Park   Hostel - 9.8km from city centre
# 44          Wombat's The City Hostel London   Hostel - 7.3km from city centre
# 45               St Christopher's Greenwich   Hostel - 4.7km from city centre
# 46       St Christopher's Oasis-Female Only   Hostel - 0.7km from city centre
# 47                  St Christopher's Camden  Hostel - 11.9km from city centre
# 48          St Christopher's Shepherds Bush   Hostel - 6.9km from city centre
# 49             St Christopher's Hammersmith   Hotel - 14.5km from city centre
#
#    Overall Review        Total Reviews  \
# 0        Fabulous     44 Total Reviews
# 1        Fabulous   9567 Total Reviews
# 2            Good   2740 Total Reviews
# 3        Fabulous     15 Total Reviews
# 4          Superb   3214 Total Reviews
# 5       Very Good   2276 Total Reviews
# 6          Superb   1055 Total Reviews
# 7       Very Good   4645 Total Reviews
# 8       Very Good   4026 Total Reviews
# 9        Fabulous   1688 Total Reviews
# 10         Superb    253 Total Reviews
# 11         Rating   3686 Total Reviews
# 12           Good    854 Total Reviews
# 13       Fabulous  11385 Total Reviews
# 14       Fabulous  13370 Total Reviews
# 15       Fabulous   3155 Total Reviews
# 16      Very Good    620 Total Reviews
# 17      Very Good   3731 Total Reviews
# 18      Very Good    642 Total Reviews
# 19       Fabulous   3972 Total Reviews
# 20      Very Good    374 Total Reviews
# 21       Fabulous    188 Total Reviews
# 22       Fabulous   6261 Total Reviews
# 23           Good   4518 Total Reviews
# 24      Very Good   1108 Total Reviews
# 25       Fabulous    188 Total Reviews
# 26         Superb   6341 Total Reviews
# 27      Very Good   3481 Total Reviews
# 28      Very Good    531 Total Reviews
# 29         Superb   1385 Total Reviews
# 30         Superb   6796 Total Reviews
# 31      Very Good   8801 Total Reviews
# 32       Fabulous  10970 Total Reviews
# 33       Fabulous    992 Total Reviews
# 34      Very Good   2795 Total Reviews
# 35         Superb   1313 Total Reviews
# 36      Very Good    803 Total Reviews
# 37      Very Good   3206 Total Reviews
# 38      Very Good   3610 Total Reviews
# 39           Good     31 Total Reviews
# 40      Very Good   1780 Total Reviews
# 41           Good    230 Total Reviews
# 42      Very Good    715 Total Reviews
# 43       Fabulous    387 Total Reviews
# 44      Very Good   3676 Total Reviews
# 45           Good    224 Total Reviews
# 46      Very Good   2448 Total Reviews
# 47      Very Good   4182 Total Reviews
# 48       Fabulous   1176 Total Reviews
# 49         Rating     17 Total Reviews
#
#                                            Facilities  \
# 0                                           Free WiFi
# 1     Free WiFi\nFollows Covid-19 sanitation guidance
# 2     Free WiFi\nFollows Covid-19 sanitation guidance
# 3                                           Free WiFi
# 4                                           Free WiFi
# 5                                      Free Breakfast
# 6                           Free WiFi\nFree Breakfast
# 7     Free WiFi\nFollows Covid-19 sanitation guidance
# 8     Free WiFi\nFollows Covid-19 sanitation guidance
# 9                           Free WiFi\nFree Breakfast
# 10                                          Free WiFi
# 11    Free WiFi\nFollows Covid-19 sanitation guidance
# 12    Free WiFi\nFollows Covid-19 sanitation guidance
# 13    Free WiFi\nFollows Covid-19 sanitation guidance
# 14    Free WiFi\nFollows Covid-19 sanitation guidance
# 15    Free WiFi\nFollows Covid-19 sanitation guidance
# 16    Free WiFi\nFollows Covid-19 sanitation guidance
# 17    Free WiFi\nFollows Covid-19 sanitation guidance
# 18    Free WiFi\nFollows Covid-19 sanitation guidance
# 19    Free WiFi\nFollows Covid-19 sanitation guidance
# 20    Free WiFi\nFollows Covid-19 sanitation guidance
# 21    Free WiFi\nFollows Covid-19 sanitation guidance
# 22                                          Free WiFi
# 23    Free WiFi\nFollows Covid-19 sanitation guidance
# 24                                          Free WiFi
# 25    Free WiFi\nFollows Covid-19 sanitation guidance
# 26    Free WiFi\nFollows Covid-19 sanitation guidance
# 27    Free WiFi\nFollows Covid-19 sanitation guidance
# 28    Free WiFi\nFollows Covid-19 sanitation guidance
# 29    Free WiFi\nFollows Covid-19 sanitation guidance
# 30    Free WiFi\nFollows Covid-19 sanitation guidance
# 31    Free WiFi\nFollows Covid-19 sanitation guidance
# 32    Free WiFi\nFollows Covid-19 sanitation guidance
# 33    Free WiFi\nFollows Covid-19 sanitation guidance
# 34    Free WiFi\nFollows Covid-19 sanitation guidance
# 35                                          Free WiFi
# 36  Free Breakfast\nFollows Covid-19 sanitation gu...
# 37    Free WiFi\nFollows Covid-19 sanitation guidance
# 38               Follows Covid-19 sanitation guidance
# 39                                          Free WiFi
# 40  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 41    Free WiFi\nFollows Covid-19 sanitation guidance
# 42                                          Free WiFi
# 43    Free WiFi\nFollows Covid-19 sanitation guidance
# 44
# 45    Free WiFi\nFollows Covid-19 sanitation guidance
# 46  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 47  Free WiFi\nFree Breakfast\nFollows Covid-19 sa...
# 48                                          Free WiFi
# 49  Free Breakfast\nFollows Covid-19 sanitation gu...
#
#                 Privates From Price              Dorms From Price
# 0             No Privates Available            Dorms From\nRs3277
# 1            Privates From\nRs12769            Dorms From\nRs1196
# 2             Privates From\nRs4984            Dorms From\nRs1718
# 3            Privates From\nRs12901  Dorms From\nRs4173.85 Rs3548
# 4             Privates From\nRs4112            Dorms From\nRs1821
# 5             Privates From\nRs6678            No Dorms Available
# 6   Privates From\nRs5533.52 Rs4980  Dorms From\nRs1673.24 Rs1506
# 7             No Privates Available            Dorms From\nRs1108
# 8             Privates From\nRs9713            Dorms From\nRs2125
# 9             Privates From\nRs6206            Dorms From\nRs2293
# 10            Privates From\nRs5565            No Dorms Available
# 11            No Privates Available             Dorms From\nRs855
# 12            Privates From\nRs6418            Dorms From\nRs2597
# 13            No Privates Available            Dorms From\nRs1720
# 14  Privates From\nRs9057.35 Rs6793  Dorms From\nRs3008.92 Rs2257
# 15  Privates From\nRs5615.97 Rs5054  Dorms From\nRs1243.03 Rs1119
# 16  Privates From\nRs6364.71 Rs5728  Dorms From\nRs1748.57 Rs1574
# 17            No Privates Available  Dorms From\nRs1516.23 Rs1365
# 18  Privates From\nRs5092.07 Rs4583  Dorms From\nRs1449.14 Rs1304
# 19  Privates From\nRs4867.22 Rs4381  Dorms From\nRs1329.23 Rs1196
# 20  Privates From\nRs7637.36 Rs6874  Dorms From\nRs1860.62 Rs1675
# 21            No Privates Available            Dorms From\nRs1922
# 22            Privates From\nRs6247            Dorms From\nRs1181
# 23            Privates From\nRs9572            Dorms From\nRs1254
# 24            Privates From\nRs8803            Dorms From\nRs2307
# 25            Privates From\nRs8502            Dorms From\nRs1907
# 26            No Privates Available            Dorms From\nRs1551
# 27  Privates From\nRs4120.41 Rs3914  Dorms From\nRs1922.81 Rs1827
# 28            Privates From\nRs7136            Dorms From\nRs2394
# 29            Privates From\nRs3609            No Dorms Available
# 30            Privates From\nRs4371            Dorms From\nRs1670
# 31            No Privates Available            Dorms From\nRs1821
# 32  Privates From\nRs5840.07 Rs5256  Dorms From\nRs1430.03 Rs1287
# 33            No Privates Available            Dorms From\nRs1686
# 34            Privates From\nRs6982            No Dorms Available
# 35            No Privates Available  Dorms From\nRs1763.93 Rs1588
# 36            No Privates Available            Dorms From\nRs2186
# 37            Privates From\nRs5734            Dorms From\nRs1720
# 38            Privates From\nRs5193            Dorms From\nRs1180
# 39  Privates From\nRs8270.68 Rs7444  Dorms From\nRs2015.77 Rs1814
# 40  Privates From\nRs6771.01 Rs6432  Dorms From\nRs2428.37 Rs2307
# 41            No Privates Available            Dorms From\nRs1956
# 42            Privates From\nRs4047            No Dorms Available
# 43            No Privates Available            Dorms From\nRs1180
# 44            Privates From\nRs3204            Dorms From\nRs1585
# 45            No Privates Available            Dorms From\nRs1821
# 46            No Privates Available            Dorms From\nRs1686
# 47            Privates From\nRs3879            Dorms From\nRs1062
# 48            Privates From\nRs4996            Dorms From\nRs1354
# 49            Privates From\nRs5396            No Dorms Available
